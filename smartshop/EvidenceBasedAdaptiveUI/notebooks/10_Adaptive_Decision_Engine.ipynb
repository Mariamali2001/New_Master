# %% [markdown]
# # Notebook 10 – Adaptive Decision Engine
#
# Simulate the **adaptive decision engine** before integration into the React e-commerce website.
#
# This notebook validates that the layered adaptation architecture works correctly.
#
# - No LLM
# - No React code
# - Only assembles the final UI configuration from repository JSON files
#
# **Pipeline order:**
#
# 1. Detect Device
# 2. Load Global Defaults
# 3. Load Device Defaults
# 4. Apply Persona Overrides
# 5. Apply Mood Overrides
# 6. Apply Personality Nudges
# 7. Produce Final UI Configuration

# %% [markdown]
# ## Inputs
#
# - `data/outputs/global_defaults.json`
# - `data/outputs/desktop_defaults.json`
# - `data/outputs/mobile_defaults.json`
# - `data/outputs/persona_overrides.json`
# - `data/outputs/mood_overrides.json`
# - `data/outputs/trait_modifiers.json`
#
# ## Outputs
#
# - `data/outputs/adaptive_engine/final_ui_configuration.json`
# - `data/outputs/adaptive_engine/adaptation_log.json`
# - `reports/AdaptiveDecisionEngine/simulation_results.xlsx`
# - `reports/AdaptiveDecisionEngine/figures/`

# %%
import json
import logging
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd


def _bootstrap_project() -> Path:
    search_from = Path.cwd().resolve()
    candidates = [search_from, *search_from.parents]
    nested_root = search_from / "EvidenceBasedAdaptiveUI"
    if (nested_root / "src" / "config.py").exists():
        candidates.insert(0, nested_root)
    for candidate in candidates:
        if (candidate / "src" / "config.py").exists():
            root = str(candidate)
            if root not in sys.path:
                sys.path.insert(0, root)
            return candidate
    raise FileNotFoundError("Could not find project root containing src/config.py.")


PROJECT_ROOT = _bootstrap_project()

from src.adaptive_engine import (
    UserContext,
    export_results,
    generate_random_contexts,
    load_repositories,
    run_adaptive_engine,
    run_batch_simulation,
)
from src.adaptive_engine.adaptive_engine import load_and_validate
from src.adaptive_engine.logger import format_log_text

logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")

INPUT_DIR = PROJECT_ROOT / "data" / "outputs"
OUTPUT_DIR = PROJECT_ROOT / "data" / "outputs" / "adaptive_engine"
REPORTS_DIR = PROJECT_ROOT / "reports" / "AdaptiveDecisionEngine"
FIGURES_DIR = REPORTS_DIR / "figures"

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
REPORTS_DIR.mkdir(parents=True, exist_ok=True)
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

print(f"Input directory: {INPUT_DIR}")
print(f"Output directory: {OUTPUT_DIR}")
print(f"Reports: {REPORTS_DIR}")
# Out:
# Input directory: /Users/mariam/Downloads/New_Master copy/smartshop/EvidenceBasedAdaptiveUI/data/outputs
# Output directory: /Users/mariam/Downloads/New_Master copy/smartshop/EvidenceBasedAdaptiveUI/data/outputs/adaptive_engine
# Reports: /Users/mariam/Downloads/New_Master copy/smartshop/EvidenceBasedAdaptiveUI/reports/AdaptiveDecisionEngine

# %% [markdown]
# ## Simulation input
#
# Replace this object with other test cases.

# %%
USER_CONTEXT = UserContext(
    persona="Explorer",
    mood="Happy",
    device="Desktop",
    personality={
        "Extraversion": "High",
        "Agreeableness": "Medium",
        "Conscientiousness": "High",
        "Neuroticism": "Low",
        "Openness": "High",
    },
)

print(json.dumps(
    {
        "persona": USER_CONTEXT.persona,
        "mood": USER_CONTEXT.mood,
        "device": USER_CONTEXT.device,
        "personality": USER_CONTEXT.personality,
    },
    indent=2,
))
# Out:
# {
#   "persona": "Explorer",
#   "mood": "Happy",
#   "device": "Desktop",
#   "personality": {
#     "Extraversion": "High",
#     "Agreeableness": "Medium",
#     "Conscientiousness": "High",
#     "Neuroticism": "Low",
#     "Openness": "High"
#   }
# }

# %% [markdown]
# ## Step 1 — Read all repositories
#
# Validate they exist. Report missing repositories.

# %%
bundle, load_report, repo_validation = load_and_validate(INPUT_DIR)

print(load_report.summary())
print("\nLoaded files:")
for filename in load_report.loaded_files:
    print(f"  ✓ {filename}")

if load_report.missing_files:
    print("\nMissing files:")
    for filename in load_report.missing_files:
        print(f"  ✗ {filename}")
    raise FileNotFoundError("Cannot continue — repository files missing.")

print("\nRepository validation:")
display(pd.DataFrame(repo_validation.checks))
# Out:
# All 6 repository files loaded from /Users/mariam/Downloads/New_Master copy/smartshop/EvidenceBasedAdaptiveUI/data/outputs
#
# Loaded files:
#   ✓ global_defaults.json
#   ✓ desktop_defaults.json
#   ✓ mobile_defaults.json
#   ✓ persona_overrides.json
#   ✓ mood_overrides.json
#   ✓ trait_modifiers.json
#
# Repository validation:
#                                  check  passed  \
# 0   All JSON files successfully loaded    True
# 1    File exists: global_defaults.json    True
# 2   File exists: desktop_defaults.json    True
# 3    File exists: mobile_defaults.json    True
# 4  File exists: persona_overrides.json    True
# 5     File exists: mood_overrides.json    True
# 6    File exists: trait_modifiers.json    True
#
#                                               detail
# 0  All 6 repository files loaded from /Users/mari...
# 1                                                 ok
# 2                                                 ok
# 3                                                 ok
# 4                                                 ok
# 5                                                 ok
# 6                                                 ok

# %% [markdown]
# ## Steps 2–3 — Load defaults and build Base UI
#
# - **Desktop** → `desktop_defaults.json` merged with global defaults
# - **Smartphone** → `mobile_defaults.json` merged with global defaults

# %%
result = run_adaptive_engine(USER_CONTEXT, bundle)

print(f"Device detected: {result.context['device']}")
print(f"Defaults source: global_defaults.json + {result.context['device_defaults']}")
print(f"Base UI elements: {len(result.base_ui)}")
display(pd.DataFrame([{"ui_element": k, "value": v} for k, v in list(result.base_ui.items())[:10]]))
# Out:
# Device detected: Desktop
# Defaults source: global_defaults.json + desktop_defaults.json
# Base UI elements: 27
#                  ui_element                                              value
# 0         accent_color_pref             Blue (Trustworthy, professional, calm)
# 1           background_pref    Cream/Off-white (Warm, comfortable, paper-like)
# 2         button_style_pref       Rounded Corners (Soft, modern rounded edges)
# 3            checkout_style  One Page (All checkout steps on a single scrol...
# 4          color_theme_pref  Minimalist Black & White (Clean, high contrast...
# 5  desktop_category_display           Visual Grid (Category tiles with images)
# 6   desktop_filter_location  Sidebar Left (Permanent filter panel on the le...
# 7         desktop_grid_pref      3 Columns (Balanced view, moderate item size)
# 8  desktop_image_text_ratio  Image-focused (80% images, 20% text - highly v...
# 9      desktop_info_density  Moderate (Balanced - some details visible, cli...

# %% [markdown]
# ## Steps 4–5 — Persona and mood overrides
#
# Persona overrides replace only matching properties. Mood overrides overwrite persona values on the same property. Every override is logged.

# %%
print(f"Persona overrides applied: {result.metadata['n_persona_overrides']}")
if result.persona_applied:
    display(pd.DataFrame(result.persona_applied))

print(f"\nMood overrides applied: {result.metadata['n_mood_overrides']}")
if result.mood_applied:
    display(pd.DataFrame(result.mood_applied))
# Out:
# Persona overrides applied: 7
#      layer              ui_element  \
# 0  persona        color_theme_pref
# 1  persona            urgency_pref
# 2  persona        form_field_style
# 3  persona       desktop_grid_pref
# 4  persona      desktop_navigation
# 5  persona   desktop_price_display
# 6  persona  desktop_review_display
#
#                                             previous  \
# 0  Minimalist Black & White (Clean, high contrast...
# 1      Both (Show both stock and time based urgency)
# 2  Rounded Border Fields (Outlined field with rou...
# 3      3 Columns (Balanced view, moderate item size)
# 4  Top Bar (Categories always visible across the ...
# 5  With Savings Highlighted (Shows discount amoun...
# 6            Recent 3- 5 (Show a few recent reviews)
#
#                                                value  confidence
# 0  Vibrant Bold (Bright, energetic colors - excit...    0.277778
# 1      None (I find these annoying and manipulative)    0.277778
# 2                 Outlined (Border around the field)    0.277778
# 3  2 Columns (Large product images, fewer items p...    0.277778
# 4  Mega Menu (Dropdown with images and subcategor...    0.333333
# 5  Strike-through Original (Shows original price ...    0.305556
# 6   All Paginated (Show all reviews with pagination)    0.500000
# Mood overrides applied: 6
#   layer                 ui_element  \
# 0  mood               urgency_pref
# 1  mood             checkout_style
# 2  mood         desktop_navigation
# 3  mood  desktop_search_visibility
# 4  mood      desktop_price_display
# 5  mood    mobile_category_display
#
#                                             previous  \
# 0      None (I find these annoying and manipulative)
# 1  One Page (All checkout steps on a single scrol...
# 2  Mega Menu (Dropdown with images and subcategor...
# 3  Always Visible Top (Large, prominent search ba...
# 4  Strike-through Original (Shows original price ...
# 5                                               None
#
#                                                value  confidence
# 0     Countdown Timers (Show "Sale ends in 2 hours")    0.250000
# 1  Progress Bar (Multi step with visual progress ...    0.550000
# 2  Mega Menu (Dropdown with images and subcategor...    0.350000
# 3  Collapsible (Search bar that expands when clic...    0.764706
# 4   With Comparison (Shows similar products' prices)    0.400000
# 5           Visual Grid (Category tiles with images)    0.350000

# %% [markdown]
# ## Step 6 — Personality nudges
#
# Nudges never replace categorical UI decisions. They only adjust supported style properties:
# information density, animation, visual richness, social proof, recommendation strength, whitespace, typography scale.

# %%
active_nudges = [n for n in result.nudges_applied if n.get("status") != "skipped"]
print(f"Trait nudges applied: {len(active_nudges)}")
if active_nudges:
    display(pd.DataFrame(active_nudges))

print("\nNudge summary (net adjustments):")
print(json.dumps(result.nudge_summary, indent=2))
# Out:
# Trait nudges applied: 5
#                trait level                 property                ui_element  \
# 0       Extraversion  High  recommendation_strength      social_proof_display
# 1       Extraversion  High      information_density      desktop_info_density
# 2  Conscientiousness  High      information_density      desktop_info_density
# 3           Openness  High          visual_richness  desktop_image_text_ratio
# 4           Openness  High          visual_richness          hero_banner_size
#
#    delta                                           previous  previous_index  \
# 0     -1         User Photos (Photos uploaded by customers)               4
# 1     -1  Moderate (Balanced - some details visible, cli...               1
# 2      1  Minimal (Only key information - product name, ...               0
# 3      1  Image-focused (80% images, 20% text - highly v...               2
# 4      1            Medium Split (Takes up half the screen)               2
#
#    new_index                                              value  confidence
# 0          3    Customer Reviews (Written reviews with ratings)    0.626089
# 1          0  Minimal (Only key information - product name, ...    0.626089
# 2          1  Moderate (Balanced - some details visible, cli...    0.319887
# 3          2  Image-focused (80% images, 20% text - highly v...    0.408289
# 4          3   Large Full screen (Takes up entire first screen)    0.408289
# Nudge summary (net adjustments):
# {
#   "visual_richness": "+1",
#   "information_density": "0",
#   "whitespace": "0",
#   "animation": "0",
#   "recommendation_strength": "-1"
# }

# %% [markdown]
# ## Step 7 — Final Adaptive UI Configuration

# %%
print(json.dumps(result.final_ui_configuration, indent=2))
# Out:
# {
#   "accent_color": "Blue",
#   "animation": "0",
#   "background": "Cream/Off-white",
#   "button_style": "Rounded Corners",
#   "category_display": "Visual Grid",
#   "checkout": "Progress Bar",
#   "color_theme": "Vibrant Bold",
#   "filter_location": "Sidebar Left",
#   "font_style": "Classic Serif",
#   "form_field": "Outlined",
#   "grid_layout": "2 Columns",
#   "hero_banner": "Large Full screen",
#   "information_density": "0",
#   "information_density_level": "Moderate",
#   "layout_whitespace": "Balanced",
#   "navigation": "Mega Menu",
#   "persistent_filters": "Yes",
#   "price_display": "With Comparison",
#   "product_card": "Info Rich",
#   "product_description": "Expandable Sections",
#   "quick_view": "Sidebar Slide",
#   "recommendation": "Deals",
#   "recommendation_strength": "-1",
#   "review_display": "All Paginated",
#   "search_visibility": "Collapsible",
#   "social_proof": "Customer Reviews",
#   "typography_scale": "Large",
#   "urgency": "Countdown Timers",
#   "visual_balance": "Image-focused",
#   "visual_richness": "+1",
#   "whitespace": "0"
# }

# %% [markdown]
# ## Step 8 — Adaptation Log

# %%
print(format_log_text(result.adaptation_log))
print("\n--- Structured log ---")
display(pd.DataFrame(result.adaptation_log["entries"]))
# Out:
# Loaded Global Defaults
# Loaded Desktop Defaults
# Applied Persona Override
#   color_theme_pref
#   Minimalist Black & White
#   ↓
#   Vibrant Bold
#
# Applied Persona Override
#   urgency_pref
#   Both
#   ↓
#   None
#
# Applied Persona Override
#   form_field_style
#   Rounded Border Fields
#   ↓
#   Outlined
#
# Applied Persona Override
#   desktop_grid_pref
#   3 Columns
#   ↓
#   2 Columns
#
# Applied Persona Override
#   desktop_navigation
#   Top Bar
#   ↓
#   Mega Menu
#
# Applied Persona Override
#   desktop_price_display
#   With Savings Highlighted
#   ↓
#   Strike-through Original
#
# Applied Persona Override
#   desktop_review_display
#   Recent 3- 5
#   ↓
#   All Paginated
#
# Applied Mood Override
#   urgency_pref
#   None
#   ↓
#   Countdown Timers
#
# Applied Mood Override
#   checkout_style
#   One Page
#   ↓
#   Progress Bar
#
# Applied Mood Override
#   desktop_navigation
#   Mega Menu
#   ↓
#   Mega Menu
#
# Applied Mood Override
#   desktop_search_visibility
#   Always Visible Top
#   ↓
#   Collapsible
#
# Applied Mood Override
#   desktop_price_display
#   Strike-through Original
#   ↓
#   With Comparison
#
# Applied Mood Override
#   mobile_category_display
#   Default
#   ↓
#   Visual Grid
#
# Applied Personality Nudge
#   Recommendation Strength
#   4
#   ↓
#   -1
#
# Applied Personality Nudge
#   Information Density
#   1
#   ↓
#   -1
#
# Applied Personality Nudge
#   Information Density
#   0
#   ↓
#   +1
#
# Applied Personality Nudge
#   Visual Richness
#   2
#   ↓
#   +1
#
# Applied Personality Nudge
#   Visual Richness
#   2
#   ↓
#   +1
#
# --- Structured log ---
#                          step            layer  \
# 0      Loaded Global Defaults         defaults
# 1     Loaded Desktop Defaults  device_defaults
# 2    Applied Persona Override          persona
# 3    Applied Persona Override          persona
# 4    Applied Persona Override          persona
# 5    Applied Persona Override          persona
# 6    Applied Persona Override          persona
# 7    Applied Persona Override          persona
# 8    Applied Persona Override          persona
# 9       Applied Mood Override             mood
# 10      Applied Mood Override             mood
# 11      Applied Mood Override             mood
# 12      Applied Mood Override             mood
# 13      Applied Mood Override             mood
# 14      Applied Mood Override             mood
# 15  Applied Personality Nudge      trait_nudge
# 16  Applied Personality Nudge      trait_nudge
# 17  Applied Personality Nudge      trait_nudge
# 18  Applied Personality Nudge      trait_nudge
# 19  Applied Personality Nudge      trait_nudge
#
#                                                detail   device  \
# 0   Merged global_defaults.json with base survey m...      NaN
# 1   Applied desktop_defaults.json.json on top of g...  Desktop
# 2                                                 NaN      NaN
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                                                 NaN      NaN
# 6                                                 NaN      NaN
# 7                                                 NaN      NaN
# 8                                                 NaN      NaN
# 9                                                 NaN      NaN
# 10                                                NaN      NaN
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13                                                NaN      NaN
# 14                                                NaN      NaN
# 15                                                NaN      NaN
# 16                                                NaN      NaN
# 17                                                NaN      NaN
# 18                                                NaN      NaN
# 19                                                NaN      NaN
#
#                      property                    before  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2            color_theme_pref  Minimalist Black & White
# 3                urgency_pref                      Both
# 4            form_field_style     Rounded Border Fields
# 5           desktop_grid_pref                 3 Columns
# 6          desktop_navigation                   Top Bar
# 7       desktop_price_display  With Savings Highlighted
# 8      desktop_review_display               Recent 3- 5
# 9                urgency_pref                      None
# 10             checkout_style                  One Page
# 11         desktop_navigation                 Mega Menu
# 12  desktop_search_visibility        Always Visible Top
# 13      desktop_price_display   Strike-through Original
# 14    mobile_category_display                   Default
# 15    Recommendation Strength                         4
# 16        Information Density                         1
# 17        Information Density                         0
# 18            Visual Richness                         2
# 19            Visual Richness                         2
#
#                       after  \
# 0                       NaN
# 1                       NaN
# 2              Vibrant Bold
# 3                      None
# 4                  Outlined
# 5                 2 Columns
# 6                 Mega Menu
# 7   Strike-through Original
# 8             All Paginated
# 9          Countdown Timers
# 10             Progress Bar
# 11                Mega Menu
# 12              Collapsible
# 13          With Comparison
# 14              Visual Grid
# 15                       -1
# 16                       -1
# 17                       +1
# 18                       +1
# 19                       +1
#
#                                                 arrow  \
# 0                                                 NaN
# 1                                                 NaN
# 2             Minimalist Black & White → Vibrant Bold
# 3                                         Both → None
# 4                    Rounded Border Fields → Outlined
# 5                               3 Columns → 2 Columns
# 6                                 Top Bar → Mega Menu
# 7   With Savings Highlighted → Strike-through Orig...
# 8                         Recent 3- 5 → All Paginated
# 9                             None → Countdown Timers
# 10                            One Page → Progress Bar
# 11                              Mega Menu → Mega Menu
# 12                   Always Visible Top → Collapsible
# 13          Strike-through Original → With Comparison
# 14                              Default → Visual Grid
# 15                                             4 → -1
# 16                                             1 → -1
# 17                                             0 → +1
# 18                                             2 → +1
# 19                                             2 → +1
#
#                   ui_element              trait level
# 0                        NaN                NaN   NaN
# 1                        NaN                NaN   NaN
# 2                        NaN                NaN   NaN
# 3                        NaN                NaN   NaN
# 4                        NaN                NaN   NaN
# 5                        NaN                NaN   NaN
# 6                        NaN                NaN   NaN
# 7                        NaN                NaN   NaN
# 8                        NaN                NaN   NaN
# 9                        NaN                NaN   NaN
# 10                       NaN                NaN   NaN
# 11                       NaN                NaN   NaN
# 12                       NaN                NaN   NaN
# 13                       NaN                NaN   NaN
# 14                       NaN                NaN   NaN
# 15      social_proof_display       Extraversion  High
# 16      desktop_info_density       Extraversion  High
# 17      desktop_info_density  Conscientiousness  High
# 18  desktop_image_text_ratio           Openness  High
# 19          hero_banner_size           Openness  High

# %% [markdown]
# ## Step 9 — Export JSON

# %%
export_paths = export_results(result, OUTPUT_DIR)
for label, path in export_paths.items():
    print(f"Exported {label}: {path}")
# Out:
# Exported final_ui_configuration: /Users/mariam/Downloads/New_Master copy/smartshop/EvidenceBasedAdaptiveUI/data/outputs/adaptive_engine/final_ui_configuration.json
# Exported adaptation_log: /Users/mariam/Downloads/New_Master copy/smartshop/EvidenceBasedAdaptiveUI/data/outputs/adaptive_engine/adaptation_log.json

# %% [markdown]
# ## Step 10 — Batch simulation (20 random users)

# %%
random_contexts = generate_random_contexts(bundle, n=20, seed=42)
batch_results, simulation_df = run_batch_simulation(random_contexts, bundle)

simulation_xlsx = REPORTS_DIR / "simulation_results.xlsx"
with pd.ExcelWriter(simulation_xlsx, engine="openpyxl") as writer:
    simulation_df.to_excel(writer, sheet_name="simulations", index=False)
    pd.DataFrame([{"ui_element": k, "value": v} for k, v in result.raw_ui_configuration.items()]).to_excel(
        writer, sheet_name="example_raw_ui", index=False
    )
    pd.DataFrame([{"component": k, "value": v} for k, v in result.final_ui_configuration.items()]).to_excel(
        writer, sheet_name="example_final_ui", index=False
    )

display(simulation_df[[
    "simulation_id", "device", "persona", "mood",
    "n_persona_overrides", "n_mood_overrides", "n_trait_nudges", "validation_ok",
]])
print(f"\nSaved: {simulation_xlsx}")
# Out:
#     simulation_id      device          persona        mood  \
# 0               1     Desktop      Deal Hunter       Happy
# 1               2     Desktop          Browser         Sad
# 2               3     Desktop       Minimalist       Bored
# 3               4  Smartphone      Deal Hunter    Stressed
# 4               5     Desktop  Impulsive Buyer  Frustrated
# 5               6  Smartphone  Impulsive Buyer     Relaxed
# 6               7  Smartphone   Loyal Customer     Excited
# 7               8     Desktop       Researcher     Excited
# 8               9  Smartphone          Browser         Sad
# 9              10  Smartphone  Impulsive Buyer       Happy
# 10             11     Desktop       Researcher  Frustrated
# 11             12  Smartphone       Researcher       Happy
# 12             13     Desktop  Impulsive Buyer     Excited
# 13             14  Smartphone   Loyal Customer         Sad
# 14             15  Smartphone       Minimalist     Neutral
# 15             16     Desktop       Minimalist    Stressed
# 16             17     Desktop       Researcher         Sad
# 17             18     Desktop  Impulsive Buyer       Bored
# 18             19  Smartphone          Browser     Neutral
# 19             20     Desktop  Impulsive Buyer  Frustrated
#
#     n_persona_overrides  n_mood_overrides  n_trait_nudges  validation_ok
# 0                     8                 6               9           True
# 1                     7                 0               9           True
# 2                     5                 5               6           True
# 3                     8                 6               8           True
# 4                     4                 0               2           True
# 5                     4                 6               6           True
# 6                    10                 4               9           True
# 7                     6                 4              10           True
# 8                     7                 0               5           True
# 9                     4                 6               1           True
# 10                    6                 0               6           True
# 11                    6                 6               3           True
# 12                    4                 4               4           True
# 13                   10                 0               5           True
# 14                    5                 5               6           True
# 15                    5                 6               5           True
# 16                    6                 0              11           True
# 17                    4                 5               3           True
# 18                    7                 5               7           True
# 19                    4                 0              10           True
# Saved: /Users/mariam/Downloads/New_Master copy/smartshop/EvidenceBasedAdaptiveUI/reports/AdaptiveDecisionEngine/simulation_results.xlsx

# %% [markdown]
# ## Visualizations

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))

axes[0].bar(
    ["Persona", "Mood", "Trait"],
    [
        simulation_df["n_persona_overrides"].mean(),
        simulation_df["n_mood_overrides"].mean(),
        simulation_df["n_trait_nudges"].mean(),
    ],
    color=["#4C78A8", "#F58518", "#54A24B"],
)
axes[0].set_title("Mean Overrides / Nudges Applied")
axes[0].set_ylabel("Count")

simulation_df["n_persona_overrides"].hist(ax=axes[1], bins=8, color="#4C78A8", edgecolor="white")
axes[1].set_title("Persona Overrides Distribution")
axes[1].set_xlabel("Count")

simulation_df["n_trait_nudges"].hist(ax=axes[2], bins=8, color="#54A24B", edgecolor="white")
axes[2].set_title("Trait Nudges Distribution")
axes[2].set_xlabel("Count")

plt.tight_layout()
override_fig = FIGURES_DIR / "override_and_nudge_counts.png"
plt.savefig(override_fig, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {override_fig}")
# Out:
# Saved: /Users/mariam/Downloads/New_Master copy/smartshop/EvidenceBasedAdaptiveUI/reports/AdaptiveDecisionEngine/figures/override_and_nudge_counts.png

# %%
components = pd.Series(result.final_ui_configuration).sort_index()
nudge_keys = {"animation", "information_density", "recommendation_strength", "visual_richness", "whitespace"}
ui_components = components[~components.index.isin(nudge_keys)]
nudge_components = components[components.index.isin(nudge_keys)]

fig, axes = plt.subplots(1, 2, figsize=(14, max(6, len(components) * 0.25)), gridspec_kw={"width_ratios": [3, 1]})

y_pos = range(len(ui_components))
axes[0].barh(list(y_pos), [1] * len(ui_components), color="#72B7B2")
axes[0].set_yticks(list(y_pos))
axes[0].set_yticklabels(ui_components.index)
axes[0].set_xlim(0, 1.35)
axes[0].set_xticks([])
axes[0].set_title("Final UI Components")
for i, value in enumerate(ui_components.values):
    axes[0].text(1.02, i, str(value), va="center", fontsize=8)

if len(nudge_components):
    nudge_values = [int(v) for v in nudge_components.values]
    axes[1].bar(nudge_components.index, nudge_values, color="#54A24B")
    axes[1].axhline(0, color="gray", linewidth=0.8)
    axes[1].set_title("Personality Nudges")
    axes[1].tick_params(axis="x", rotation=45)
else:
    axes[1].set_visible(False)

plt.tight_layout()
components_fig = FIGURES_DIR / "final_ui_components.png"
plt.savefig(components_fig, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {components_fig}")
# Out:
# Saved: /Users/mariam/Downloads/New_Master copy/smartshop/EvidenceBasedAdaptiveUI/reports/AdaptiveDecisionEngine/figures/final_ui_components.png

# %% [markdown]
# ## Validation

# %%
validation_df = pd.DataFrame(result.validation["checks"])
display(validation_df)

all_batch_valid = simulation_df["validation_ok"].all()
print(f"\nAll batch simulations valid: {all_batch_valid}")
if result.warnings:
    print("Warnings:", result.warnings)
# Out:
#                                     check  passed              detail
# 0                 No duplicate properties    True  28 keys, 28 unique
# 1           No missing UI property values    True      0 empty values
# 2   All required global UI elements exist    True         all present
# 3  All required Desktop UI elements exist    True         all present
# All batch simulations valid: True
# Warnings: ["No trait nudges found for Neuroticism = 'Low'."]

# %% [markdown]
# ## Final summary

# %%
print("Simulation Successful")
print("Repository Loaded")
print("Final UI Generated")
print(f"Number of Persona Overrides Applied: {result.metadata['n_persona_overrides']}")
print(f"Number of Mood Overrides Applied: {result.metadata['n_mood_overrides']}")
print(f"Number of Nudges Applied: {result.metadata['n_trait_nudges']}")
print("Export completed successfully.")
# Out:
# Simulation Successful
# Repository Loaded
# Final UI Generated
# Number of Persona Overrides Applied: 7
# Number of Mood Overrides Applied: 6
# Number of Nudges Applied: 5
# Export completed successfully.
