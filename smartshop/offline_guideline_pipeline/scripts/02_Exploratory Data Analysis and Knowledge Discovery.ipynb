# %% [markdown]
# ## Evidence-Based Adaptive User Interface Framework for E-Commerce
#
# Objectives
# Understand participant demographics
# Analyze shopping behavior
# Analyze personality traits
# Analyze mood distribution
# Analyze desktop UI preferences
# Analyze mobile UI preferences
# Discover potential adaptation patterns
# Produce publication-quality figures
# Generate reports for the thesis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from pathlib import Path

# %%
df=pd.read_csv("/Users/mariam/Downloads/New_Master copy/smartshop/offline_guideline_pipeline/scripts/data/processed/clean_dataset.csv")

print(df.shape)

print(df.info())

print(df.describe(include="all"))
# Out:
# (195, 74)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Timestamp                    195 non-null    object
#  1   consent                      195 non-null    object
#  2   age_group                    195 non-null    object
#  3   gender                       195 non-null    object
#  4   education_level              195 non-null    object
#  5   primary_device               195 non-null    object
#  6   shopping_motivation          195 non-null    object
#  7   decision_speed               195 non-null    object
#  8   price_sensitivity            195 non-null    object
#  9   review_importance            195 non-null    object
#  10  brand_loyalty                195 non-null    object
#  11  social_proof_influence       195 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                     0
# consent                       0
# age_group                     0
# gender                        0
# education_level               0
#                              ..
# mobile_touch_size             0
# expects_device_adaptation     0
# adaptation_comfort            0
# delight_factors              66
# frustration_points           68
# Length: 74, dtype: int64
